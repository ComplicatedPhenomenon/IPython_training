# %%
# %cd /Users/kylewong/Playground/GL/CollectionsofScripts/
# Out:
# /Users/kylewong/Playground/GL/CollectionsofScripts

# %%
from zhihu_oauth import ZhihuClient, Answer, Article
client = ZhihuClient()
client.login_in_terminal(username=None, password=None, use_getpass=True, captcha_filename=None)
# Out:
# ----- Zhihu OAuth Login -----
# 使用手机号登录的时候请在手机号前加上 +86
# email/phone: +8615210311877
# password: ········
# Need for a captcha, getting it......
# Please open /Users/kylewong/Playground/GH/IPython_Takeoff/captcha.gif for captcha
# captcha: xfex
# Login success.
# (True, '')

# %%
q2 = client.question(43454328)
i = 1
for q in q2.answers:
    if i < 4: # define the number of answers you want to print
        print (q.content)
        print (q.author.name)
        print ("---------------------")
        print ("|     DIVID LINE    |")
        print ("---------------------")
        for c in  q.comments:
            print (c.author.name)
            print (c.content)
            print ("---------------------")
            print ("---------------------")
        i = i+1
    else:
        exit()
# Out:
# Witten 在数学物理中的贡献非常多，可以形容为用物理学尖锐的直觉刺破了数学界以“严密逻辑”构成的坚硬外壳，把部分数学家和数学思想从按部就班的、严格的方法论中解放了出来，也让许多物理学家逐渐深入到数学界中，意识到“原来研究物理也能研究到深刻的数学”。更重要的是，他的工作暗示着，a) 物理系统中各种 ill-defined 的对象，比如他总是在用的路径积分，有着 robust 的 well-defined 的内核；b) 超对称量子物理对于养育自己的流形的精细结构是很敏感的，超对称BPS态就像一些平衡态，如一些散落在形状复杂的势能极小点的小球，而量子效应则像从这些经典状态伸展出来爬满整个流形的触手，通过研究这些触手，就可以得知许多流形的信息。<br><br>Witten 比较家喻户晓的数学贡献是：<br>1）Jones 多项式与量子 Chern-Simons 理论。<br>2）Donaldson-Witten 理论<br>3）Seiberg-Witten 理论<br>4）Gromov-Witten 理论<br><br>1）<img src="https://www.zhihu.com/equation?tex=S%5E3" alt="S^3" eeimg="1">上<img src="https://www.zhihu.com/equation?tex=SU%282%29" alt="SU(2)" eeimg="1"> Chern-Simons 理论（<img src="https://www.zhihu.com/equation?tex=k" alt="k" eeimg="1">为其作用量前的整数系数）的配分函数和 Wilson-loops（属<img src="https://www.zhihu.com/equation?tex=SU%282%29" alt="SU(2)" eeimg="1">不可约表示）的关联函数可以用路径积分和 Localization 来严格计算。鉴于 Chern-Simons 作用量的拓扑不变性，这个泛函积分也自动具有拓扑不变性，从而奠定了其为 Wilson-loop 定义域（一些链接）的拓扑不变量。最后算完这个路径积分，归一化后变成 <img src="https://www.zhihu.com/equation?tex=q+%5Cequiv+%5Cexp%7B%5Cfrac%7B2i+%5Cpi%7D%7Bk%2B2%7D%7D" alt="q \equiv \exp{\frac{2i \pi}{k+2}}" eeimg="1"> 的多项式。经查实，与 Jones 多项式刚好一样，这些关于<img src="https://www.zhihu.com/equation?tex=q" alt="q" eeimg="1">的多项式是<img src="https://www.zhihu.com/equation?tex=S%5E3" alt="S^3" eeimg="1">中的扭结、链结的拓扑不变量。<br><br>2）Donaldson 发展弗里德曼对 4 维黎曼流形<img src="https://www.zhihu.com/equation?tex=M" alt="M" eeimg="1">拓扑分类的结果，利用<img src="https://www.zhihu.com/equation?tex=M" alt="M" eeimg="1">上的瞬子的模空间<img src="https://www.zhihu.com/equation?tex=%5Cmathcal%7BM%7D" alt="\mathcal{M}" eeimg="1">上的交截理论来计算<img src="https://www.zhihu.com/equation?tex=M" alt="M" eeimg="1">的微分不变量。Witten 决定把 1）的方法推到 4 维。Witten 提出 topological twist 的方法，把“超对称不变量”和“拓扑不变量”联系在一起。通过 localization 计算 <img src="https://www.zhihu.com/equation?tex=%5Cmathcal%7BN%7D%3D2" alt="\mathcal{N}=2" eeimg="1"> twisted 理论的配分函数和 BPS 算符的关联函数，发现这些物理量其实对应瞬子模空间<img src="https://www.zhihu.com/equation?tex=%5Cmathcal%7BM%7D" alt="\mathcal{M}" eeimg="1">的交截数，从而用物理方法获得了黎曼流形的 Donaldson 微分不变量。<br><br>3）基于 2) 的结果，还有与 Seiberg 一同发展的电磁对偶理论，他们决定考虑研究上面这个理论在低能时候的行为。最后他们得到一个<img src="https://www.zhihu.com/equation?tex=M" alt="M" eeimg="1">上的阿贝尔规范场论，其 BPS 位形给出的不是瞬子，而是一组新的非线性微分方程。这组非线性微分方程的解空间同样携带了关于 <img src="https://www.zhihu.com/equation?tex=M" alt="M" eeimg="1"> 微分结构的信息，在一定条件下与 Donaldson-Witten 不变量等价。这组微分方程后来称为 Seiberg-Witten 方程，是数学家研究辛几何的重要工具。<br><br>4）另一套研究辛几何的工具，Gromov-Witten 不变量，同样是 Witten 的重要贡献之一。方法与上面 2) 类似，研究 2 维黎曼曲面<img src="https://www.zhihu.com/equation?tex=%5CSigma" alt="\Sigma" eeimg="1"> 上<img src="https://www.zhihu.com/equation?tex=%5Cmathcal%7BN%7D+%3D+%282%2C2%29" alt="\mathcal{N} = (2,2)" eeimg="1"> 超对称理论，并定义相应的 topological twist。其中一种 twist 使得理论的 BPS 位形刚好是 <img src="https://www.zhihu.com/equation?tex=%5CSigma" alt="\Sigma" eeimg="1"> 到另一个 Kahler 空间的全纯映射（全纯曲线），而相应的配分函数、BPS 关联函数则又是这些全纯曲线的模空间上的交截理论。这些交截理论又是早前辛几何中重要的 Gromov 辛不变量。由这个工作发展出来一个庞大的体系，即 Mirror Symmetry，是拓扑弦学家和代数几何学家和谐共处的领域。<br><br>Witten 的重要工作还有很多。他的触手延伸到理论物理的各个角落，大多我也不清楚的领域。可以说，他是目前数学物理界的教皇。他获得菲尔兹奖，也是实至名归。
# 史诗生物
# ---------------------
# |     DIVID LINE    |
# ---------------------
# 更深的蓝
# 作为一个理工科学生，我表示，每个汉字甚至每个单词我都能认识，但是连在一起，就是不知道在讲什么。。。
# ---------------------
# ---------------------
# 白开水
# 1）和2）的工作是88和89年做的，4）Gromov-Witten不变量应该是93年阮勇斌和田刚构造的，3）Selberg-Witten 方程是94年的工作，所以Witten拿90年菲尔兹奖的时候还是有不少人觉得他有点不够（跟其他获奖者比起来）。
# ---------------------
# ---------------------
# 孙剑
# 全是干货看不懂，只能以赞聊表谢意
# ---------------------
# ---------------------
# 大鱼
# 一脸懵逼
# ---------------------
# ---------------------
# 史诗生物
# 我读稍微超出自己熟悉的方向的论文也是这种感觉。
# ---------------------
# ---------------------
# 陈庆之
# 不明觉厉！！
# ---------------------
# ---------------------
# Mr.qiao
# 啊哈，果然你又评论了。
# ---------------------
# ---------------------
# 王得福wizard
# 搞数学的果然生活在形而上的理念世界里啊，工科人看得都懵逼了。
# ---------------------
# ---------------------
# 猫头鹰green
# 留个记号
# ---------------------
# ---------------------
# 别走
# 指标定理拓扑部分witten形变
# ---------------------
# ---------------------
# zhaosj
# ”每个字都认识但是一脸懵“系列
# ---------------------
# ---------------------
# Matrixor
# 以后的数学估计要从其它学科来弥补了
# ---------------------
# ---------------------
# 王道猷
# 家喻户晓？
# ---------------------
# ---------------------
# 杜水晶牛
# 啊啊啊啊啊啊  好厉害 但是还是啥都不懂
# ---------------------
# ---------------------
# 史诗生物
# 用了夸张的修辞手法
# ---------------------
# ---------------------
# 史诗生物
# 在产生新想法新方法上，每个学科都会需要从其周边学科借鉴。数学几千年的发展正是从许多其他领域吸取营养慢慢壮大。
# ---------------------
# ---------------------
# Darui
# “Witten比较家喻户晓的数学贡献是”这句把我看哭了😭
# ---------------------
# ---------------------
# 回声箭
# 数学家太可怕了
# ---------------------
# ---------------------
# bluefish
# 看不懂
# ---------------------
# ---------------------
# 笑叹
# = =很多听说过的名词= =然而并不懂意思
# ---------------------
# ---------------------
# 魔都雅博
# 医学🐶表示一脸懵逼
# ---------------------
# ---------------------
# 小狼
# 蒙逼
# ---------------------
# ---------------------
# 肥肥肥肥肥
# 我对不起“家喻户晓”这四个字
# ---------------------
# ---------------------
# the N
# 什么都没能看懂，看完之后只记得“触手”
# ---------------------
# ---------------------
# 跃方
# 为什么我看到“家喻户晓”四个字，有一种想哭的感觉
# ---------------------
# ---------------------
# 王凡
# 好答案 但是“家喻户晓”四字用于本文任何地方都不合适
# ---------------------
# ---------------------
# 熊猫
# 楼上的，你们好吗？我只想问一句：“文章的内容会影响我明天吃早饭吗？”
# ---------------------
# ---------------------
# Mig Silent
# 很多其他领域的论文我都能看懂个七七八八，这篇数学的我就跪了……果然数学都是神...( ＿ ＿)ノ｜
# ---------------------
# ---------------------
# 张辰LMY
# 感觉层主说的都是后来被数学界逐渐证实而获得认可的，层主的证据在于说明Witten有资格拿菲尔兹奖。 比如大名鼎鼎的Seiberg-Witten 理论大概是从1994年才传开的（见《规范理论与4维几何的新展开》这篇文章），而Witten是1990获得菲尔兹奖。所以说，Witten当年拿菲尔兹奖，自身能力是基础，大佬Atiyah的力荐是关键。试想，陈省身的贡献完全有资格那菲尔兹奖，当年为什么不颁给他。陈老爷子最有名的两个数学工作都是在34岁前后做出来的。
# ---------------------
# ---------------------
# Ted Chiang
# 每一个字都认识
# ---------------------
# ---------------------
# 张涛
# 看球不懂，不过你问我姿瓷不姿瓷？当然姿瓷！要是英文名词换成中文就更棒了
# ---------------------
# ---------------------
# 史诗生物
# 是的，我对 Witten 获奖时数学各界情况也不了解，只能根据他各项工作的后续重要性来进行评论。另外我觉得 Atiyah 也是想借机会向物理工作者发出亲善的政治信号，以这个奖鼓励数学和物理更多的交流。
# ---------------------
# ---------------------
# 钱峰
# 不明给赞
# ---------------------
# ---------------------
# 苏小小
# Witten1984那篇susy and Morse theory被认为是拓扑场论的开山之作
# ---------------------
# ---------------------
# 忘掉了自己
# 每个字我都看懂了。
# ---------------------
# ---------------------
# mesheus
# 很厉害的。M理论创造者，初中时候就觉得他超棒!超崇拜，虽然形象不这么好。
# ---------------------
# ---------------------
# xi wu
# 干货！
# ---------------------
# ---------------------
# 踏歌而行
# 虽然一点都看不懂，但我还是看看能不能记住几个术语
# ---------------------
# ---------------------
# 种一颗小树
# 在数学家圈子里家喻户晓
# ---------------------
# ---------------------
# Ligang
# 那是一个犹太人，物理学家，数学家，他的存在说明这个世界还是the GOD说了算的，我等玉帝,太上老君的选民估计还要一个世纪吧。
# ---------------------
# ---------------------
# 黃郁錡
# 跪求數學大神解惑～<br>假設Witten在40歲時貢獻為100<br>那麼史上唯一的女菲爾茲獎得主Maryam Mirzakhani大概是多少呀？<br>30！？
# ---------------------
# ---------------------
# 黃郁錡
# 其實是Atiyah和Witten交情很好<br>他甚至有點崇拜Witten<br>Quanta Magazine有訪問過Atiyah
# ---------------------
# ---------------------
# 燃烧的船
# 不知道他在搞什么，但看起来好像很厉害的样子
# ---------------------
# ---------------------
# 汲川
# 4)中提到的 mirror symmetry 和宇称是一个东西吗，或者有没有什么联系？为什么被认为是个庞大的体系呢？
# ---------------------
# ---------------------
# 史诗生物
# 不是同一个东西。这里说的 Mirror symmetry 指的是一些 Calabi-Yau 流形的上同调群通过某个方式相连，或者在 N=(2,2) 2 维规范理论、非线性 Sigma 模型之间的对应关系。是个很庞大的话题。
# ---------------------
# ---------------------
# 瑞瑞
# <p>家喻户晓。。。。。</p>
# ---------------------
# ---------------------
# 郝浩
# <p>不存在的，大统一理论，直接把上帝之力，玉帝之力，真主之力还有佛主之力统一起来了。</p>
# ---------------------
# ---------------------
# 梦想啊还活在梦中
# 数学物理界的教皇应该是法国高等科学研究院的马克西姆-孔采维奇
# ---------------------
# ---------------------
# 丹牛
# 孔采维奇更加厉害
# ---------------------
# ---------------------
# 抛个砖吧。<br><br>我自认我说不清楚TQFT、Chern－Simons Theory 和 Jones Polynomial 之间的关系。不过还是贴一下前两天看到Michael Freedman的这篇小传：<a href="https://link.zhihu.com/?target=http%3A//it.sohu.com/20160424/n445890531.shtml" class=" external" target="_blank" rel="nofollow noreferrer"><span class="invisible">http://</span><span class="visible">it.sohu.com/20160424/n4</span><span class="invisible">45890531.shtml</span><span class="ellipsis"></span></a><br><blockquote><p>　　1988年，弗里德曼在哈佛大学出席了一场被其称之为可改变人生的研讨会，研讨会的主题是讨论爱德华·威腾（Edward Witten，现供职于普林斯顿高等研究院）近几年的工作，<b>这位数学家将扭结和链环的拓扑理论与某一物理学领域联系了起来，即现在的所谓拓扑量子场论</b>。弗里德曼当时已经意识到，扭结或链环的“琼斯多项式”计算是一个极其困难的计算问题，但解决这一难题的方案反过来又可以为解决其他很多计算问题提供思路。威腾的研究成果似乎表明，特定物理系统可瞬间完成琼斯多项式的计算。</p><p>　　“我们应该构建一台以威腾所描述的物理学为基础的电脑，它可以用来解决那些极其复杂的问题，我很快便被这样的想法所深深吸引。”他说。</p></blockquote>
# 匿名用户
# ---------------------
# |     DIVID LINE    |
# ---------------------
# Miraclemilk
# 我们应该构建一台以威腾的物理学为基础的电脑。。。
# ---------------------
# ---------------------
# 匿名用户
# 这就是拓扑量子计算最早的动机之一（另一部分就是用于纠错的 Toric Code）。因为 TQFT 能很自然地计算 Jones Polynomial（具体分类还有一些细节），当然，后来 Michael、Kitaev 还有王正汉老师证明了其实这东西的计算能力和通用量子计算机是一样的。
# ---------------------
# ---------------------
# 张乐陶
# 也许我们应该构建一套以威腾为基础的膜拜系统……
# ---------------------
# ---------------------
# 张三
# 这套系统由来已久了吧……
# ---------------------
# ---------------------
# 万里
# 打开机箱，里面坐着一个witten
# ---------------------
# ---------------------
# 张乐陶
# 哦？那我孤陋寡闻了，不妨说来听听。
# ---------------------
# ---------------------
# 张三
# 反正聊起Witten大家都会进入膜拜模式
# ---------------------
# ---------------------
# 张乐陶
# 嗯，那还膜别人吗？
# ---------------------
# ---------------------
# 张xx
# <p>  网友，您好，在吗？不好意思打扰您了，就是不知道可不可以和您在知乎私信里聊聊，给您在知乎私信里发了私信。  </p><p>就是我不知道您的用户名是什么没法给您发私信。 </p>
# ---------------------
# ---------------------
# 题主可以尝试去看一两本关于String Theory的书。<br><br>1. Michael Atiyah对Edward Witten的评价，里面介绍了他的贡献：<a href="https://link.zhihu.com/?target=http%3A//mathunion.org/ICM/ICM1990.1/Main/icm1990.1.0031.0036.ocr.pdf" class=" wrap external" target="_blank" rel="nofollow noreferrer">On the Work of Edward Witten</a><br><br>2. Ed Witten 的文章发表数据（HEP-th与相关领域）<figure><img src="https://pic1.zhimg.com/aad1b44753a634718f510106dd1ac740_b.png" data-rawwidth="640" data-rawheight="480" class="origin_image zh-lightbox-thumb" width="640" data-original="https://pic1.zhimg.com/aad1b44753a634718f510106dd1ac740_r.jpg"></figure>Ed Witten在1990年拿到的Fields Metal,。他在1985年那一年的文章发表量是26篇。这26篇中包括 <a class=" wrap external" href="https://link.zhihu.com/?target=http%3A//inspirehep.net/record/220076" target="_blank" rel="nofollow noreferrer">Noncommutative Geometry and String Field Theory</a> 和 <a class=" wrap external" href="https://link.zhihu.com/?target=http%3A//inspirehep.net/record/16270" target="_blank" rel="nofollow noreferrer">Vacuum Configurations for Superstrings</a> 这样高质量和高Citation的 Paper，是前无史人的工作效率。<br>3. 此外，<a class=" wrap external" href="https://link.zhihu.com/?target=http%3A//inspirehep.net/record/467400" target="_blank" rel="nofollow noreferrer">Anti-de Sitter space and holography</a>是一篇经典文章。那么的经典以至于所有进入string theory的学者都会反反复复的研读它。
# 匿名用户
# ---------------------
# |     DIVID LINE    |
# ---------------------
