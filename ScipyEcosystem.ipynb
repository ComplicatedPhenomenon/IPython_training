# %% [markdown]
# ### Numerical python ecosystem
#
# #### Numpy
# #### Pandas
# #### Matplotlib
# #### Scipy
# * Cadabra
#
# #### Machine Learning

# %% [markdown]
# [dfm found a mistake in the previous paper](http://dfm.io/posts/fitting-a-plane/)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt 
import numpy as np 
def show(ori_func, ft, sampling_period = 5): 
    n = len(ori_func) 
    interval = sampling_period / n 
    # 绘制原始函数
    plt.subplot(2, 1, 1) 
    plt.plot(np.arange(0, sampling_period, interval), ori_func, 'black') 
    plt.xlabel('Time'), plt.ylabel('Amplitude') 
    # 绘制变换后的函数
    plt.subplot(2,1,2) 
    frequency = np.arange(n / 2) / (n * interval) 
    nfft = abs(ft[range(int(n / 2))] / n ) 
    plt.plot(frequency, nfft, 'red') 
    plt.xlabel('Freq (Hz)'), plt.ylabel('Amp. Spectrum') 
    plt.show()

# %%
# ?plt.subplot

# %%
import matplotlib

# %%
matplotlib.

# %%
# 生成频率为 1（角速度为 2 * pi）的正弦波
time = np.arange(0, 5, .005) 
x = np.sin(2 * np.pi * 1 * time) 
y = np.fft.fft(x) 
show(x, y)

# %%
len(x)
# Out:
# 1000

# %%
len(time)
# Out:
# 1000

# %%
# ?np.arange

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(np.arange)
# Out:
# builtin_function_or_method

# %%
# ?np.fft.fft

# %%
# 将其与频率为 20 和 60 的波叠加起来
x2 = np.sin(2 * np.pi * 20 * time) 
x3 = np.sin(2 * np.pi * 60 * time) 
x += x2 + x3 
y = np.fft.fft(x) 
show(x, y)

# %%
# 生成方波，振幅是 1，频率为 10Hz
# 我们的间隔是 0.05s，每秒有 200 个点
# 所以需要每隔 20 个点设为 1
x = np.zeros(len(time)) 
x[::20] = 1 
y = np.fft.fft(x) 
show(x, y)

# %%
# 生成脉冲波
x = np.zeros(len(time)) 
x[380:400] = np.arange(0, 1, .05) 
x[400:420] = np.arange(1, 0, -.05) 
y = np.fft.fft(x) 
show(x, y)

# %%
# 生成脉冲波
x = np.zeros(len(time)) 
x[380:400] = np.arange(0, 1, .05) 
x[400:420] = np.arange(1, 0, -.05) 
y = np.fft.fft(x) 
show(x, y)

# %% [markdown]
# $$A_k\sum_{m=0}^{n-1}a_m exp\{-2\pi i\frac{mk}{n}\} \,\, k= 0, 1, ..., n-1$$

# %%
x = np.random.random(500) 
n = len(x) 
m = np.arange(n) 
k = m.reshape((n, 1)) 
M = np.exp(-2j * np.pi * k * m / n) 
y = np.dot(M, x) 

np.allclose(y, np.fft.fft(x))
# Out:
# True

# %%
# 傅里叶逆变换
M2 = np.exp(2j * np.pi * k * m / n) 
x2 = np.dot(y, M2) / n 
np.allclose(x, x2) 
# True 
np.allclose(x, np.fft.ifft(y)) 
# True
# Out:
# True

# %%
# 创建 10 个 0~9 随机整数的信号
a = np.random.randint(10, size = 10) 
a 
# array([7, 4, 9, 9, 6, 9, 2, 6, 8, 3]) 
a.mean() 
# 6.2999999999999998 
# 进行傅里叶变换
A = np.fft.fft(a) 
A 
'''
array([ 63.00000000 +0.00000000e+00j,   
        -2.19098301 -6.74315233e+00j, 
        -5.25328890 +4.02874005e+00j, 
        -3.30901699 -2.40414157e+00j, 
        13.75328890 -1.38757276e-01j,    
      1.00000000 -2.44249065e-15j, 
        13.75328890 +1.38757276e-01j, 
     -3.30901699 +2.40414157e+00j, 
        -5.25328890 -4.02874005e+00j, 
     -2.19098301 +6.74315233e+00j])
'''
# Out:
# '\narray([ 63.00000000 +0.00000000e+00j,   \n        -2.19098301 -6.74315233e+00j, \n        -5.25328890 +4.02874005e+00j, \n        -3.30901699 -2.40414157e+00j, \n        13.75328890 -1.38757276e-01j,    \n      1.00000000 -2.44249065e-15j, \n        13.75328890 +1.38757276e-01j, \n     -3.30901699 +2.40414157e+00j, \n        -5.25328890 -4.02874005e+00j, \n     -2.19098301 +6.74315233e+00j])\n'
