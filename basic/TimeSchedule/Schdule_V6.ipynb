# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import random

# %%
import json
import copy

# %%
import time
import datetime

# %%
from collections import Counter

# %%
from termcolor import colored

# %% [markdown]
# # Prepare the data structure

# %%
# Slot = Index , Day , Hour
class SlotProcessor:
    def __init__(self, inputString):
        stringParts = inputString.split(",")
        cursorPosition = 0
        self.id = stringParts[cursorPosition].strip()
        cursorPosition += 1
        self.day = stringParts[cursorPosition].strip()
        cursorPosition += 1
        self.time = stringParts[cursorPosition].strip()
    """        
    def getSlotInfo(self):
        print('Index: {} | Day: {} | Hour:{}'.format(self.id, self.day, self.time))
    """

# %%
# Room = Index , Name , Capacity
class RoomProcessor:
    def __init__(self, inputString):
        stringParts = inputString.split(",")
        cursorPosition = 0

        self.id = stringParts[cursorPosition].strip()
        cursorPosition += 1

        self.name = stringParts[cursorPosition].strip()
    """
    def getRoomInfo(self):
        print('Index: {} | name: {}'.format(self.id, self.name))
    """

# %%
#  Course = Index , Name , Capacity , Arrangement , InstructorIndex
class CourseProcessor:
    def __init__(self, inputString):
        stringParts = inputString.split(",")
        cursorPosition = 0

        self.id = stringParts[cursorPosition].strip()
        cursorPosition += 1

        self.name = stringParts[cursorPosition].strip()
        cursorPosition += 1

        self.capacity = stringParts[cursorPosition].strip()
        cursorPosition += 1

        self.arrangement = stringParts[cursorPosition].strip()
        cursorPosition += 1

        self.instructorIndex = int(stringParts[cursorPosition].strip())
   
    def getCourseInfo(self):
        print("Course ID: {} | Course Name: {} | Roomtype: {} | Arrangement: {} | InstructorIndex: {}"\
              .format(self.id, self.name, self.capacity, self.arrangement, self.instructorIndex))
        
    def getCourseName(self):
        return self.name
    def getCourseInstructorIndex(self):
        return int(self.instructorIndex)

# %%
# Instructor = Index , Name 
class InstructorProcessor:
    def __init__(self, inputString):
        stringParts = inputString.split(",")
        cursorPosition = 0

        self.id = stringParts[cursorPosition].strip()
        cursorPosition += 1

        self.name = stringParts[cursorPosition].strip()
        cursorPosition += 1
     
    def getInstructorIndex(self):
        return int(self.id)
    
    def getInstructorName(self):
        return self.name
    
    def getInstructorInfo(self):
        print("Instructor ID: {} | Instructor Name: {}".format(self.id, self.name))
    
    # Highlight function getInstructorNameViaIndex(instructorIndex)
    def getInstructorNameViaIndex(self, instructorIndex):
        if int(self.id) == instructorIndex:
            print (self.name) 
        else:
            print('There is no instructor with this instructor index')

# %%
slots = []
rooms = []
courses = []
instructors = []
with open('input4.txt') as fp:
    for line in fp:
        if line.startswith("#"):
        # ignore comments in input file
            continue
        lineSections = line.split("=")
        # print(lineSections)
        if lineSections[0].strip() == "Slot":
            #1 , one    ,  8:00
            # print(lineSections[1])
            slots.append(SlotProcessor(lineSections[1]))
            # slots
        elif lineSections[0].strip() == "Room":
            rooms.append(RoomProcessor(lineSections[1]))
        elif lineSections[0].strip() == "Course":
            courses.append(CourseProcessor(lineSections[1]))
        elif lineSections[0].strip() == "Instructor":
            instructors.append(InstructorProcessor(lineSections[1]))

#print('number of slots: {}, number of rooms: {}, number of courses: {}, number of instructors: {}'.\
#     format(len(slots), len(rooms), len(courses), len(instructors)))

# %%
class courseInstructor:
    def __init__(self, an_item_in_courses, an_item_in_instructors):
        self.course = an_item_in_courses        
        self.instructor = an_item_in_instructors
    
    def printCourseInstructorInfo(self): # Don't forget situation that 2 teachers may have the same name.
        return('course name: {} | instructor name: {}'.\
              format(self.course.getCourseName(),\
                     self.instructor.getInstructorName()))

# %% [markdown]
# # Class schedule

# %%
def InstructorNotAvailable(which_class, CurrentInstructor, ExistedSlots, which_slot):
    if which_class == 1:
        return False
    else:
        i = 1
        a = 0
        while i < which_class:          
            if CurrentInstructor == ExistedSlots[which_slot - 40 * i][0].instructor.getInstructorIndex():
                a += 1
            else:
                a += 0
            
            i += 1
        if a == 0:
            return False
        else:
            return True

# %%
class Schedule:
    def __init__(self, slots, rooms, courses, instructors):
        self.schedule_slots = slots
        self.schedule_rooms = rooms
        self.schedule_courses = courses
        self.schedule_instructors = instructors
        self.slotsInfo = []
        self.slots = []
        self.fitness = 0.0
        self.generation = 1
        self.number_of_courses_for_a_class_per_week = len(self.schedule_slots)
        self.weekday = 5
        self.number_of_courses_for_a_class_per_day=self.number_of_courses_for_a_class_per_week/self.weekday

        for i in range(0, len(slots) * len(rooms)): 
            self.slots.append([]) 
            
    def inspectSchedule(self):
        if self.slots[0] == []:
                print('Wake up, before looking up the schedule, create it at first!')
        else:
                
            for i in range(0, len(slots) * len(rooms)):
                print( 'CourseInstructorInfo: {} | {}'\
                      .format(self.slots[i][0].printCourseInstructorInfo(), i))
    # only can be called once        
    def createSchedule(self):
        number_of_courses_for_all_classes_per_week = len(self.slots) # 240
        number_of_course_types = len(self.schedule_courses)//len(self.schedule_rooms) 
        initial_choice = [list(range(0,40)), list(range(40,80)),\
                          list(range(80,120)), list(range(120,160)),\
                          list(range(160,200)), list(range(200,240))]
        
        for course in self.schedule_courses:           
            slotContent = courseInstructor(course, self.schedule_instructors[course.getCourseInstructorIndex() - 1])
            classIndex=(int(course.id)+15)//number_of_course_types
            InstructorIndex = course.getCourseInstructorIndex() # type(classIndex) is float
            repeated_times_for_a_course = int(course.arrangement[1])
            j = 0 
            while j < repeated_times_for_a_course:
                if len(initial_choice[classIndex - 1]) > 1:
                    abondon_choice_1, abondon_choice_2 = random.sample(initial_choice[classIndex - 1], 2) 
                    abondon_choice = abondon_choice_2 if InstructorNotAvailable(classIndex, InstructorIndex, self.slots, abondon_choice_1)\
                    else abondon_choice_1
                else: 
                    abondon_choice = initial_choice[classIndex - 1][0] 
                        
                self.slots[abondon_choice].append(slotContent)
                """
                print('OKAY! The {}th course :{}, place it to the {}th slot'.format(counter_the_number_of_arranged_course,course.getCourseName(), abondon_choice))
                counter_the_number_of_arranged_course += 1
                print(self.slots[abondon_choice][0].printCourseInstructorInfo()) # Different from Version1
                """
                initial_choice[classIndex - 1].remove(abondon_choice)
                j = j + 1    
        
        for k in range(0, len(self.slots)):
            self.slotsInfo.append(self.slots[k][0])

# %%
class Schedule:
    def __init__(self, slots, rooms, courses, instructors):
        self.schedule_slots = slots
        self.schedule_rooms = rooms
        self.schedule_courses = courses
        self.schedule_instructors = instructors
        self.slotsInfo = []
        self.slots = []
        self.fitness = 0.0
        self.generation = 1
        self.number_of_courses_for_a_class_per_week = len(self.schedule_slots)
        self.weekday = 5
        self.number_of_courses_for_a_class_per_day=self.number_of_courses_for_a_class_per_week/self.weekday

        for i in range(0, len(slots) * len(rooms)): 
            self.slots.append([]) 
            
    def inspectSchedule(self):
        if self.slots[0] == []:
                print('Wake up, before looking up the schedule, create it at first!')
        else:
                
            for i in range(0, len(slots) * len(rooms)):
                print( 'CourseInstructorInfo: {} | {}'\
                      .format(self.slots[i][0].printCourseInstructorInfo(), i))
    # only can be called once        
    def createSchedule(self):
        number_of_courses_for_all_classes_per_week = len(self.slots) # 240
        number_of_course_types = len(self.schedule_courses)//len(self.schedule_rooms) 
        initial_choice = [list(range(0,40)), list(range(40,80)),\
                          list(range(80,120)), list(range(120,160)),\
                          list(range(160,200)), list(range(200,240))]
        
        for course in self.schedule_courses:           
            slotContent = courseInstructor(course, self.schedule_instructors[course.getCourseInstructorIndex() - 1])
            classIndex=(int(course.id)+15)//number_of_course_types
            InstructorIndex = course.getCourseInstructorIndex() # type(classIndex) is float
            repeated_times_for_a_course = int(course.arrangement[1])
            j = 0 
            while j < repeated_times_for_a_course:
                if len(initial_choice[classIndex - 1]) > 1:
                    abondon_choice_1, abondon_choice_2 = random.sample(initial_choice[classIndex - 1], 2) 
                    abondon_choice = abondon_choice_2 if InstructorNotAvailable(classIndex, InstructorIndex, self.slots, abondon_choice_1)\
                    else abondon_choice_1
                else: 
                    abondon_choice = initial_choice[classIndex - 1][0] 
                        
                self.slots[abondon_choice].append(slotContent)
                """
                print('OKAY! The {}th course :{}, place it to the {}th slot'.format(counter_the_number_of_arranged_course,course.getCourseName(), abondon_choice))
                counter_the_number_of_arranged_course += 1
                print(self.slots[abondon_choice][0].printCourseInstructorInfo()) # Different from Version1
                """
                initial_choice[classIndex - 1].remove(abondon_choice)
                j = j + 1    
        
        for k in range(0, len(self.slots)):
            self.slotsInfo.append(self.slots[k][0])

# %%
class Schedule:
    def __init__(self, slots, rooms, courses, instructors):
        self.schedule_slots = slots
        self.schedule_rooms = rooms
        self.schedule_courses = courses
        self.schedule_instructors = instructors
        self.slotsInfo = []
        self.slots = []
        self.fitness = 0.0
        self.generation = 1
        self.number_of_courses_for_a_class_per_week = len(self.schedule_slots)
        self.weekday = 5
        self.number_of_courses_for_a_class_per_day=self.number_of_courses_for_a_class_per_week/self.weekday

        for i in range(0, len(slots) * len(rooms)): 
            self.slots.append([]) 
            
    def inspectSchedule(self):
        if self.slots[0] == []:
                print('Wake up, before looking up the schedule, create it at first!')
        else:
                
            for i in range(0, len(slots) * len(rooms)):
                print( 'CourseInstructorInfo: {} | {}'\
                      .format(self.slots[i][0].printCourseInstructorInfo(), i))
    # only can be called once        
    def createSchedule(self):
        number_of_courses_for_all_classes_per_week = len(self.slots) # 240
        number_of_course_types = len(self.schedule_courses)//len(self.schedule_rooms) 
        initial_choice = [list(range(0,40)), list(range(40,80)),\
                          list(range(80,120)), list(range(120,160)),\
                          list(range(160,200)), list(range(200,240))]
        
        for course in self.schedule_courses:           
            slotContent = courseInstructor(course, self.schedule_instructors[course.getCourseInstructorIndex() - 1])
            classIndex=(int(course.id)+15)//number_of_course_types
            InstructorIndex = course.getCourseInstructorIndex() # type(classIndex) is float
            repeated_times_for_a_course = int(course.arrangement[1])
            
            if repeated_times_for_a_course >=3:
                j = 0 
                while j < repeated_times_for_a_course:
                    xx = [0+j*8, 4+j*8]
                    abondon_choice_1, abondon_choice_2 = random.sample(xx, 2) 
                    abondon_choice = abondon_choice_2 if InstructorNotAvailable(classIndex, InstructorIndex, self.slots, abondon_choice_1)\
                    else abondon_choice_1

                    self.slots[abondon_choice].append(slotContent)
                    xx.remove(abondon_choice)
                    initial_choice[classIndex - 1].remove(abondon_choice)
                    j = j + 1
            
            if repeated_times_for_a_course < 3:
                j = 0 
                while j < repeated_times_for_a_course:
                    if len(initial_choice[classIndex - 1]) > 1:
                        abondon_choice_1, abondon_choice_2 = random.sample(initial_choice[classIndex - 1], 2) 
                        abondon_choice = abondon_choice_2 if InstructorNotAvailable(classIndex, InstructorIndex, self.slots, abondon_choice_1)\
                        else abondon_choice_1
                    else: 
                        abondon_choice = initial_choice[classIndex - 1][0] 

                    self.slots[abondon_choice].append(slotContent)
                    initial_choice[classIndex - 1].remove(abondon_choice)
                    j = j + 1    
        
        for k in range(0, len(self.slots)):
            self.slotsInfo.append(self.slots[k][0])

# %%
ScheduleTable = Schedule(slots, rooms, courses, instructors )
ScheduleTable.createSchedule()
ScheduleTable.inspectSchedule()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-60268fdfb2ee> in <module>()
#       1 ScheduleTable = Schedule(slots, rooms, courses, instructors )
# ----> 2 ScheduleTable.createSchedule()
#       3 ScheduleTable.inspectSchedule()
#
# <ipython-input-62-eaa1ddfb950f> in createSchedule(self)
#      44                     self.slots[abondon_choice].append(slotContent)
#      45                     xx.remove(abondon_choice)
# ---> 46                     initial_choice[classIndex - 1].remove(abondon_choice)
#      47                     j = j + 1
#      48
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# # define Fitness calculation

# %% [markdown]
# ## Fitness for eight classes a day

# %% [markdown]
# **Evaluate a course order in a day**

# %% [markdown]
# Cut`ScheduleTable.slotsInfo`  into slices, A slices represents the courses for a class a day

# %% [markdown]
# ##  Fitness for final schedule of class

# %%
def getCourseToBeEvaluated(ScheduleTable): # ScheduleTable.slotsInfo
    courseToBeEvaluated = []
    for i in range(0,30):
        courseToBeEvaluated.append([])
    i = 0
    for k in ScheduleTable.slotsInfo: # ScheduleTable.slotsInfo
        m =  i // 8        
        courseToBeEvaluated[m].append(k)
        i += 1
    return courseToBeEvaluated 

def getScheduleOfClass(courseToBeEvaluated):
    ScheduleOfClass = []
    x = len(courseToBeEvaluated)
    for i in range(x):
        ScheduleOfClass.append([[], []])
        
    for i in range(x):
        for j in courseToBeEvaluated[i]:
            ScheduleOfClass[i][0].append(j.course.name)
            ScheduleOfClass[i][1].append(j.course.arrangement)
    return ScheduleOfClass

def calculateFitness(ScheduleOfClass):
    mark = 0
    for ooo in ScheduleOfClass:
        a = calculateFitnessForAStrip(ooo)
        mark += a
    return mark

# %%
import math
math.log10(8**15)
# Out:
# 13.546349804879155

# %%
def calculateFitnessForAStrip(courseForADayAClass):
    getMark = 0
    className = courseForADayAClass[0]
    classArr= courseForADayAClass[1]
    nameCountDict = dict(Counter(className[0:4]))
    x = len(list(dict(Counter(className)).values()))

    if '语文' in className[0:4] and nameCountDict['语文'] ==1:   
        getMark +=5
    if '语文' in className[0:4] and nameCountDict['语文'] !=1:   
        getMark -=5
    if '语文' not in className[0:4]:   
        getMark -=5
    if '数学' in className[0:4] and nameCountDict['数学'] ==1:
        getMark +=5 
    if '数学' in className[0:4] and nameCountDict['数学'] !=1:
        getMark -=5  
    if '数学' not in className[0:4]:
        getMark -=5  
    if '英语' in className[0:4] and nameCountDict['英语'] ==1:
        getMark +=5 
    if '英语' in className[0:4] and nameCountDict['英语'] !=1:
        getMark -=5 
    if '英语' not in className[0:4]:
        getMark -=5 
    if '语文' in className[4:8]:
        getMark -=9
    if '数学' in className[4:8]:
        getMark -=9
    if '英语' in className[4:8]:
        getMark -= 9
    
    if 'A1' in classArr[0:4]:
        getMark -=8
    if 'A2' in classArr[0:4]:
        getMark -=8 
    
    if 'A1' in classArr[4:8]:
        getMark +=5 
    if 'A2' in classArr[4:8]:
        getMark +=5 

    if x==8:
        getMark +=10
    elif x == 7:
        getMark -= 5
    else:
        getMark -= 10
          
    return getMark

# %%
"""
def calculateFitnessForAStrip(courseForADayAClass):
    getMark = 0
    className = courseForADayAClass[0]
    classArr= courseForADayAClass[1]
    nameCountDict = dict(Counter(className[0:4]))
   # x = len(list(dict(Counter(className)).values()))

    if '语文' in className[0:4] and nameCountDict['语文'] ==1:   
        getMark += 5
            
    return getMark
"""

# %% [markdown]
# # Mutate a available schedule

# %%
for i in range(0, 6):
    classIndex1, classIndex2 = random.sample(range(40 * i, 40 * i + 40), 2)
    while classIndex1 > classIndex2:
        classIndex1, classIndex2 = random.sample(range(40 * i, 40 * i + 40), 2)
    print(classIndex1, classIndex2)
# Out:
# 22 35
# 68 77
# 83 111
# 154 155
# 170 189
# 213 228

# %%
"""
def validMutation(ScheduleTable):
    p4 = copy.deepcopy(ScheduleTable)
    TimesOfInvalidMutation = 0
    for i in range(0, 6):
        classIndex1, classIndex2 = random.sample(range(40 * i, 40 * i + 40), 2)
        while InstructorNotAvailable(i+1, p4.slots[classIndex1][0].course.getCourseInstructorIndex(), p4.slots,  classIndex1) or \
              InstructorNotAvailable(i+1, p4.slots[classIndex2][0].course.getCourseInstructorIndex(), p4.slots,  classIndex2):
            TimesOfInvalidMutation += 1
            classIndex1, classIndex2 = random.sample(range(40 * i, 40 * i + 40), 2)
            print(colored("Times of Invalid mutaion: {}".format(TimesOfInvalidMutation),'red'))
            
            if TimesOfInvalidMutation > 20:
                # To make the return value same as input 
                p4.slotsInfo[classIndex1], p4.slotsInfo[classIndex2] = p4.slotsInfo[classIndex2], p4.slotsInfo[classIndex1] 
                ScheduleTable.generation = ScheduleTable.generation - 1
                print(colored('Prepare to stop the iteration','red'))
                break
            
        p4.slotsInfo[classIndex1], p4.slotsInfo[classIndex2] = p4.slotsInfo[classIndex2], p4.slotsInfo[classIndex1]    
        p4.generation = ScheduleTable.generation + 1
    
    return p4
"""

# %%
def validMutation(ScheduleTable):
    p4 = copy.deepcopy(ScheduleTable)
    t1 = random.randint(0, 5) 
    TimesOfInvalidMutation = 0

    classIndex1, classIndex2 = random.sample(range(40 * t1, 40 * t1 + 40), 2)
    while InstructorNotAvailable(t1+1, p4.slots[classIndex1][0].course.getCourseInstructorIndex(), p4.slots,  classIndex1) or \
          InstructorNotAvailable(t1+1, p4.slots[classIndex2][0].course.getCourseInstructorIndex(), p4.slots,  classIndex2):
        
        TimesOfInvalidMutation += 1
        classIndex1, classIndex2 = random.sample(range(40 * t1, 40 * t1 + 40), 2)
        print(colored("Times of Invalid mutaion: {}".format(TimesOfInvalidMutation),'red'))
        if TimesOfInvalidMutation > 20:
            # To make the return value same as input 
            p4.slotsInfo[classIndex1], p4.slotsInfo[classIndex2] = p4.slotsInfo[classIndex2], p4.slotsInfo[classIndex1] 
            ScheduleTable.generation = ScheduleTable.generation - 1
            print(colored('Prepare to stop the iteration','red'))
            break
   # print(colored('Mutation is valid now', 'green'))   
    p4.slotsInfo[classIndex1], p4.slotsInfo[classIndex2] = p4.slotsInfo[classIndex2], p4.slotsInfo[classIndex1]    
    p4.generation = ScheduleTable.generation + 1
    
    return p4

# %% [markdown]
# ### Test `validMutation`

# %%
ScheduleTable = Schedule(slots, rooms, courses, instructors )
ScheduleTable.createSchedule()
bestParent = ScheduleTable
courseToBeEvaluated = getCourseToBeEvaluated(bestParent)
scheduleOfClass = getScheduleOfClass(courseToBeEvaluated)
bestFitness = calculateFitness(scheduleOfClass)
x = 0
while True: 
    child = validMutation(bestParent) 
    #print(x)
    if child == bestParent:
        break
    courseToBeEvaluated = getCourseToBeEvaluated(child)
    scheduleOfClass = getScheduleOfClass(courseToBeEvaluated)
    childFitness = calculateFitness(scheduleOfClass)
    
    #print("parentFitness = {} | childFitness= {}".format(bestFitness, childFitness))
    if bestFitness >= childFitness:
        x += 1
        if x > 220:
            break
        continue  
    x = 0
    bestFitness = childFitness 
    #print("bestFitness = {}".format(bestFitness))
    bestParent = child  
bestParent.inspectSchedule()
# Out:
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 2
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# Times of Invalid mutaion: 1
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 0
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 1
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 2
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 3
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 4
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 5
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 6
# CourseInstructorInfo: course name: 化学 | instructor name: 张文云 | 7
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 8
# CourseInstructorInfo: course name: 心理健康 | instructor name: 李发德 | 9
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 10
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 11
# CourseInstructorInfo: course name: 体育 | instructor name: 马晶 | 12
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 13
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 14
# CourseInstructorInfo: course name: 写字书法 | instructor name: 周锦坤 | 15
# CourseInstructorInfo: course name: 语文 | instructor name: 许梅 | 16
# CourseInstructorInfo: course name: 语文 | instructor name: 许梅 | 17
# CourseInstructorInfo: course name: 劳技 | instructor name: 周剑 | 18
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 19
# CourseInstructorInfo: course name: 语文 | instructor name: 许梅 | 20
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 21
# CourseInstructorInfo: course name: 语文 | instructor name: 许梅 | 22
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 23
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 24
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 25
# CourseInstructorInfo: course name: 化学 | instructor name: 张文云 | 26
# CourseInstructorInfo: course name: 语文 | instructor name: 许梅 | 27
# CourseInstructorInfo: course name: 化学 | instructor name: 张文云 | 28
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 29
# CourseInstructorInfo: course name: 美术 | instructor name: 何自雄 | 30
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 31
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 32
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 33
# CourseInstructorInfo: course name: 体育 | instructor name: 马晶 | 34
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 35
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 36
# CourseInstructorInfo: course name: 音乐 | instructor name: 李一明 | 37
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 38
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 39
# CourseInstructorInfo: course name: 语文 | instructor name: 王绍坤 | 40
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 41
# CourseInstructorInfo: course name: 语文 | instructor name: 王绍坤 | 42
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 43
# CourseInstructorInfo: course name: 语文 | instructor name: 王绍坤 | 44
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 45
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 46
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 47
# CourseInstructorInfo: course name: 体育 | instructor name: 马晶 | 48
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 49
# CourseInstructorInfo: course name: 化学 | instructor name: 张文云 | 50
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 51
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 52
# CourseInstructorInfo: course name: 语文 | instructor name: 王绍坤 | 53
# CourseInstructorInfo: course name: 美术 | instructor name: 何自雄 | 54
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 55
# CourseInstructorInfo: course name: 语文 | instructor name: 王绍坤 | 56
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 57
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 58
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 59
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 60
# CourseInstructorInfo: course name: 劳技 | instructor name: 周剑 | 61
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 62
# CourseInstructorInfo: course name: 数学 | instructor name: 马云芝 | 63
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 64
# CourseInstructorInfo: course name: 化学 | instructor name: 张文云 | 65
# CourseInstructorInfo: course name: 体育 | instructor name: 马晶 | 66
# CourseInstructorInfo: course name: 心理健康 | instructor name: 李发德 | 67
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 68
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 69
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 70
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 71
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 72
# CourseInstructorInfo: course name: 音乐 | instructor name: 李一明 | 73
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 74
# CourseInstructorInfo: course name: 英语 | instructor name: 罗迎春 | 75
# CourseInstructorInfo: course name: 写字书法 | instructor name: 周锦坤 | 76
# CourseInstructorInfo: course name: 化学 | instructor name: 张文云 | 77
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 78
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 79
# CourseInstructorInfo: course name: 写字书法 | instructor name: 周锦坤 | 80
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 81
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 82
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 83
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 84
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 85
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 86
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 87
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 88
# CourseInstructorInfo: course name: 地理 | instructor name: 地理老师1 | 89
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 90
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 91
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 92
# CourseInstructorInfo: course name: 化学 | instructor name: 李发高 | 93
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 94
# CourseInstructorInfo: course name: 体育 | instructor name: 马晶 | 95
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 96
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 97
# CourseInstructorInfo: course name: 心理健康 | instructor name: 李发德 | 98
# CourseInstructorInfo: course name: 生物 | instructor name: 生物老师1 | 99
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 100
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 101
# CourseInstructorInfo: course name: 英语 | instructor name: 姚焕杨 | 102
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 103
# CourseInstructorInfo: course name: 英语 | instructor name: 姚焕杨 | 104
# CourseInstructorInfo: course name: 英语 | instructor name: 姚焕杨 | 105
# CourseInstructorInfo: course name: 化学 | instructor name: 李发高 | 106
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师1 | 107
# CourseInstructorInfo: course name: 劳技 | instructor name: 周剑 | 108
# CourseInstructorInfo: course name: 英语 | instructor name: 姚焕杨 | 109
# CourseInstructorInfo: course name: 音乐 | instructor name: 李一明 | 110
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 111
# CourseInstructorInfo: course name: 体育 | instructor name: 马晶 | 112
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 113
# CourseInstructorInfo: course name: 化学 | instructor name: 李发高 | 114
# CourseInstructorInfo: course name: 美术 | instructor name: 何自雄 | 115
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 116
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 117
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 118
# CourseInstructorInfo: course name: 物理 | instructor name: 吴发祥 | 119
# CourseInstructorInfo: course name: 物理 | instructor name: 刀俊翔 | 120
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师2 | 121
# CourseInstructorInfo: course name: 体育 | instructor name: 杨丽 | 122
# CourseInstructorInfo: course name: 英语 | instructor name: 姚焕杨 | 123
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 124
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 125
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 126
# CourseInstructorInfo: course name: 化学 | instructor name: 李发高 | 127
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 128
# CourseInstructorInfo: course name: 历史 | instructor name: 刘俊娇 | 129
# CourseInstructorInfo: course name: 政治 | instructor name: 政治老师2 | 130
# CourseInstructorInfo: course name: 数学 | instructor name: 李进勇 | 131
# CourseInstructorInfo: course name: 化学 | instructor name: 李发高 | 132
# CourseInstructorInfo: course name: 写字书法 | instructor name: 周锦坤 | 133
# CourseInstructorInfo: course name: 劳技 | instructor name: 周剑 | 134
# CourseInstructorInfo: course name: 道德法制 | instructor name: 黄庆猛 | 135
# CourseInstructorInfo: course name: 英语 | instructor name: 姚焕杨 | 136
# CourseInstructorInfo: course name: 语文 | instructor name: 刘伟 | 137
# CourseInstructorInfo: course name: 美术 | instructor name: 何自雄 | 138
# CourseInstructorInfo: course nam
# <b>limit_output extension: Maximum message size of 10000 exceeded with 16797 characters</b>
